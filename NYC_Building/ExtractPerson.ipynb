# %%
import pandas as pd
import numpy as np

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

# %%
from bs4 import BeautifulSoup as BS

# %%
from time import sleep

# %%
import csv

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('personLinks.csv')

# %%
df.head()
# Out:
#               Name                                               Link
# 0  AAFOUALLAH RIAD  https://a810-bisweb.nyc.gov/bisweb/LicenseQuer...
# 1    AAMAR ZEESHAN  https://a810-bisweb.nyc.gov/bisweb/LicenseQuer...
# 2    AAMER MUSHTAQ  https://a810-bisweb.nyc.gov/bisweb/LicenseQuer...
# 3    AANTUNES LUIS  https://a810-bisweb.nyc.gov/bisweb/LicenseQuer...
# 4      AARON BROYN  https://a810-bisweb.nyc.gov/bisweb/LicenseQuer...

# %%
# Start the Selenium WebDriver
path = r'chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
driver.get(df['Link'][1])

# %%
page = driver.page_source

soup = BS(page, "lxml")
body = soup.find('body')
center = body.find('center')
table = center.find_all('table')

# %%
for index, item in enumerate(table):
    print(index)
    print(item)
    print("**********************************")
# Out:
# 0
# <table border="0" cellpadding="3" cellspacing="0" width="100%"> <!--- Start of Header --->
# <tbody><tr>
# <td align="center" class="header" colspan="3" width="100%">
# <div class="noprint">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody><tr>
# <td class="header">
# 				  <a href="bsqpm01.jsp">BIS Menu</a>  |  License Query
# 						</td>
# <td align="right" class="header2">  <a href="http://www1.nyc.gov/site/buildings/property-or-business-owner/project-process-frequently-asked-questions.page">FAQs</a>  |  <a href="http://www1.nyc.gov/site/buildings/dob/acronym-glossary.page">Glossary</a>
#
# 							<script language="javascript">
# 							<!---
# 								print_today();
# 							//--->
# 							</script>  May 18, 2023
# 								<script language="javascript">
# 	<!--
# 		function page(loc, ref)
# 		{
# 			//Commented out the usagelog creation for Caching on 4-30-15
# 			//var ce = (document.cookie == null || document.cookie == "") ? "n" : "y";
# 			//var u = 'Log/img.gif?m=pg&url='+escape(loc)+'&ref='+escape(ref)+'&ra='+Math.round(Math.random()*100000)+'&ce='+ce;
# 			//(new Image(1,1)).src = u;
# 		}
#
# 		//onclick="page('/path/place', document.location);"
#
#                 var _gaq = _gaq || [];
#                 _gaq.push(['_setAccount', 'UA-16591777-1']);
#                 _gaq.push(['_trackPageview']);
#
#                 (function() {
#                         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#                         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#                         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#                 })();
#
# 	//-->
# 	</script>
# <!--Webtrends-->
# <script type="text/javascript">
#                 var prod_dcsId_val = "dcs222nsor5tv2djuwohyn2so_2m6k";
#                 var prod_host = "a810-bisweb.nyc.gov";
# </script>
# <script src="https://www1.nyc.gov/assets/home/js/webtrends/webtrends_v10.js" type="text/javascript"></script>
# <!--End Web Trends - MC added back on 8/30/18 -->
# </td>
# </tr>
# </tbody></table>
# </div>
# </td>
# </tr>
# <tr>
# <td colspan="2"><a href="./bispi00.jsp"><img alt="DOB Logo - Link to Homepage" border="0" src="./images/doblogo_1.jpg"/></a></td> <!--- Cell for DOB Logo --->
# <td align="right"><a href="http://www1.nyc.gov/site/buildings/index.page"><img alt="NYC.gov Logo - Link to Homepage" border="0" src="./images/nyclogo.gif"/></a>
# <br/>
# <a href="https://www1.nyc.gov/site/buildings/dob/subscribe-to-buildings-news.page" onclick="javascript:page('/ext/signupnews', document.location);">
# <img border="0" onmouseout="this.src='images/clckhere.gif';" onmouseover="this.src='images/clckhere_over.gif';" src="images/clckhere.gif"/>
# </a>
# </td>
# </tr>
# <tr>
# <td align="center" class="nychdg" colspan="3"><b>NYC Department of Buildings</b></td>
# </tr>
# <tr>
# <td align="center" class="mainhdg" colspan="3">Contractor Details</td>
# </tr>
# </tbody></table>
# **********************************
# 1
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody><tr>
# <td class="header">
# 				  <a href="bsqpm01.jsp">BIS Menu</a>  |  License Query
# 						</td>
# <td align="right" class="header2">  <a href="http://www1.nyc.gov/site/buildings/property-or-business-owner/project-process-frequently-asked-questions.page">FAQs</a>  |  <a href="http://www1.nyc.gov/site/buildings/dob/acronym-glossary.page">Glossary</a>
#
# 							<script language="javascript">
# 							<!---
# 								print_today();
# 							//--->
# 							</script>  May 18, 2023
# 								<script language="javascript">
# 	<!--
# 		function page(loc, ref)
# 		{
# 			//Commented out the usagelog creation for Caching on 4-30-15
# 			//var ce = (document.cookie == null || document.cookie == "") ? "n" : "y";
# 			//var u = 'Log/img.gif?m=pg&url='+escape(loc)+'&ref='+escape(ref)+'&ra='+Math.round(Math.random()*100000)+'&ce='+ce;
# 			//(new Image(1,1)).src = u;
# 		}
#
# 		//onclick="page('/path/place', document.location);"
#
#                 var _gaq = _gaq || [];
#                 _gaq.push(['_setAccount', 'UA-16591777-1']);
#                 _gaq.push(['_trackPageview']);
#
#                 (function() {
#                         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#                         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#                         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#                 })();
#
# 	//-->
# 	</script>
# <!--Webtrends-->
# <script type="text/javascript">
#                 var prod_dcsId_val = "dcs222nsor5tv2djuwohyn2so_2m6k";
#                 var prod_host = "a810-bisweb.nyc.gov";
# </script>
# <script src="https://www1.nyc.gov/assets/home/js/webtrends/webtrends_v10.js" type="text/javascript"></script>
# <!--End Web Trends - MC added back on 8/30/18 -->
# </td>
# </tr>
# </tbody></table>
# **********************************
# 2
# <table align="center" border="0" cellpadding="3" cellspacing="0" width="750">
# <tbody><tr valign="top">
# <td align="center" class="largelabel" colspan="7" style="color:red; font-weight:bold">
# </td>
# </tr>
# </tbody></table>
# **********************************
# 3
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="750">
# <tbody><tr>
# <td class="tblhdg"><div align="center">=== GENERAL CONTRACTOR - REGISTERED ===</div></td>
# </tr>
# <tr>
# <td class="tblhdg"><div align="center"> INCLUDING NEW 1/2/3 FAMILY HOMES </div></td>
# </tr>
# <tr>
# <td align="center" class="centercolhdg">
# <b>ZEESHAN                     AAMAR</b>
# </td>
# </tr>
# <tr>
# <td>
# <table border="0" cellpadding="1" cellspacing="0" width="100%">
# <tbody><tr>
# <td><img alt="" height="1" src="./images/Clear.gif" width="200"/></td><td><img alt="" height="1" src="./images/Clear.gif" width="150"/></td><td><img alt="" height="1" src="./images/Clear.gif" width="200"/></td><td><img alt="" height="1" src="./images/Clear.gif" width="150"/></td><td><img alt="" height="1" src="./images/Clear.gif" width="30"/></td></tr>
# <tr>
# <td class="content"><b>
#
#
# 						Date Registered:
#
#
# 					</b>  09/19/2017
# 					</td>
# <td class="content" colspan="2"><b>Contractor ID:</b>  617984</td>
# <td class="content">
# </td>
# <td class="centercontent">
# </td>
# </tr>
# <tr>
# <td class="content"><b>Status:</b>  E - EXPIRED</td>
# <td class="content" colspan="3"><b>Expiration:</b>  04/30/2023</td>
# <td class="content"></td>
# </tr>
# <tr><td class="content" colspan="5"><b>City Employee:   </b>No</td></tr>
# <tr>
# <td class="content" colspan="5"><b>Office Address:  </b>1754 EAST 53RD STREET   BROOKLYN, NY 11234</td>
# </tr>
# <tr>
# <td class="content" colspan="2"><b>Business Phone:  </b>718-941-9000</td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# <tr>
# <td colspan="4">
# <table border="0" cellpadding="1" cellspacing="0" width="100%">
# </table>
# </td>
# </tr>
# <tr>
# <td class="content"> </td>
# </tr>
# <tr>
# <td>
# <table border="0" cellpadding="1" cellspacing="2" width="100%">
# <tbody><tr>
# <td class="content">
# <b>Business 1  :</b>  SPEEDWAY CONSTRUCTION COR
# 					</td>
# </tr>
# <tr>
# <td class="center" colspan="5"> </td>
# </tr>
# <tr>
# <td class="centercolhdg">Insurance Type</td>
# <td class="centercolhdg">Policy</td>
# <td class="centercolhdg">Required</td>
# <td class="centercolhdg">Company</td>
# <td class="centercolhdg">Expiration Date</td>
# </tr>
# <tr>
# <td class="content"><b>General Liability</b></td>
# <td class="centercontent">CONNYF155671194</td>
# <td class="centercontent">Yes</td>
# <td class="centercontent">ILLINOIS UNION INSURANCE</td>
# <td class="centercontent">06/17/2023</td>
# </tr>
# <tr>
# <td class="content"><b>Workers' Compensation</b></td>
# <td class="centercontent">K2423 419-7</td>
# <td class="centercontent">Yes</td>
# <td class="centercontent">NYSIF</td>
# <td class="centercontent">08/02/2023</td>
# </tr>
# <tr>
# <td class="content"><b>Disability</b></td>
# <td class="centercontent">DBL511041</td>
# <td align="center" class="centercontent">Yes</td>
# <td class="centercontent">SHELTERPOINT LIFE INSURAN</td>
# <td class="centercontent">08/01/2023</td>
# </tr>
# <tr>
# <td class="content" colspan="5"> </td>
# </tr>
# <tr>
# <td class="content" colspan="5"> </td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# <!-- Backend will set flag to N if Endorsement is not applicable//-->
# <tr>
# <td class="content" colspan="5"> </td>
# </tr>
# <tr>
# <td class="centercolhdg" colspan="5">Endorsements</td>
# </tr>
# <tr>
# <td class="content" colspan="5"><b>Status:</b>  ACTIVE    <b>Type:</b>  CN - CONSTRUCTION
#
# 							<!--<b>&nbsp;&nbsp;Added:</b>&nbsp;&nbsp;12/14/2020&nbsp;&nbsp;&nbsp;&nbsp;-->
# </td>
# </tr>
# <tr>
# <td class="content" colspan="5"><b>Status:</b>  ACTIVE    <b>Type:</b>  CC - CONCRETE
#
# 							<!--<b>&nbsp;&nbsp;Added:</b>&nbsp;&nbsp;05/05/2021&nbsp;&nbsp;&nbsp;&nbsp;-->
# </td>
# </tr>
# <tr>
# <td class="content" colspan="5"><b>Status:</b>  ACTIVE    <b>Type:</b>  DM - DEMOLITION
#
# 							<!--<b>&nbsp;&nbsp;Added:</b>&nbsp;&nbsp;05/05/2021&nbsp;&nbsp;&nbsp;&nbsp;-->
# </td>
# </tr>
# </tbody></table>
# **********************************
# 4
# <table border="0" cellpadding="1" cellspacing="0" width="100%">
# <tbody><tr>
# <td><img alt="" height="1" src="./images/Clear.gif" width="200"/></td><td><img alt="" height="1" src="./images/Clear.gif" width="150"/></td><td><img alt="" height="1" src="./images/Clear.gif" width="200"/></td><td><img alt="" height="1" src="./images/Clear.gif" width="150"/></td><td><img alt="" height="1" src="./images/Clear.gif" width="30"/></td></tr>
# <tr>
# <td class="content"><b>
#
#
# 						Date Registered:
#
#
# 					</b>  09/19/2017
# 					</td>
# <td class="content" colspan="2"><b>Contractor ID:</b>  617984</td>
# <td class="content">
# </td>
# <td class="centercontent">
# </td>
# </tr>
# <tr>
# <td class="content"><b>Status:</b>  E - EXPIRED</td>
# <td class="content" colspan="3"><b>Expiration:</b>  04/30/2023</td>
# <td class="content"></td>
# </tr>
# <tr><td class="content" colspan="5"><b>City Employee:   </b>No</td></tr>
# <tr>
# <td class="content" colspan="5"><b>Office Address:  </b>1754 EAST 53RD STREET   BROOKLYN, NY 11234</td>
# </tr>
# <tr>
# <td class="content" colspan="2"><b>Business Phone:  </b>718-941-9000</td>
# </tr>
# </tbody></table>
# **********************************
# 5
# <table border="0" cellpadding="1" cellspacing="0" width="100%">
# </table>
# **********************************
# 6
# <table border="0" cellpadding="1" cellspacing="2" width="100%">
# <tbody><tr>
# <td class="content">
# <b>Business 1  :</b>  SPEEDWAY CONSTRUCTION COR
# 					</td>
# </tr>
# <tr>
# <td class="center" colspan="5"> </td>
# </tr>
# <tr>
# <td class="centercolhdg">Insurance Type</td>
# <td class="centercolhdg">Policy</td>
# <td class="centercolhdg">Required</td>
# <td class="centercolhdg">Company</td>
# <td class="centercolhdg">Expiration Date</td>
# </tr>
# <tr>
# <td class="content"><b>General Liability</b></td>
# <td class="centercontent">CONNYF155671194</td>
# <td class="centercontent">Yes</td>
# <td class="centercontent">ILLINOIS UNION INSURANCE</td>
# <td class="centercontent">06/17/2023</td>
# </tr>
# <tr>
# <td class="content"><b>Workers' Compensation</b></td>
# <td class="centercontent">K2423 419-7</td>
# <td class="centercontent">Yes</td>
# <td class="centercontent">NYSIF</td>
# <td class="centercontent">08/02/2023</td>
# </tr>
# <tr>
# <td class="content"><b>Disability</b></td>
# <td class="centercontent">DBL511041</td>
# <td align="center" class="centercontent">Yes</td>
# <td class="centercontent">SHELTERPOINT LIFE INSURAN</td>
# <td class="centercontent">08/01/2023</td>
# </tr>
# <tr>
# <td class="content" colspan="5"> </td>
# </tr>
# <tr>
# <td class="content" colspan="5"> </td>
# </tr>
# </tbody></table>
# **********************************

# %%
allFinalData = []

# %%
for link in df['Link']:
    
    sleep(1)
    driver = webdriver.Chrome(path)
    sleep(2)
    
    driver.get(link)


    # NEW PAGE
    # SCRAPING THE DATA FROM THESE PAGE

    page = driver.page_source

    soup = BS(page, "lxml")
    body = soup.find('body')
    center = body.find('center')
    table = center.find_all('table')
    
    for index, item in enumerate(table):

        if (index == 3):

            safetyarr = []
            tablearr = []
            endorsementarr = []

            tbody = item.find('tbody')
            tr = tbody.find_all('tr')

            for idx, row in enumerate(tr):

                if(idx == 1):
                    rawName = row.find_all('td', class_='centercolhdg')

                    for itemName in rawName:
                        name = itemName.text
                        safetyarr.append(name)
                        # print(name)
                        # print("++++++++++++++")

                if(idx == 4):
                    dateCont = row.find_all('td', class_='content')

                    for i, itemDateCont in enumerate(dateCont):
                        if(i == 0):
                            date = itemDateCont.text
                            safetyarr.append(date)
                            # print(date)
                        if(i == 1):
                            contId = itemDateCont.text
                            safetyarr.append(contId)
                        #     print(contId)
                        #
                        # print("+++++++++++++++")


                if (idx == 5):
                    statusExp = row.find_all('td', class_='content')

                    for i, itemstatusExp in enumerate(statusExp):
                        if (i == 0):
                            status1 = itemstatusExp.text
                            safetyarr.append(status1)
                            # print(status1)
                        if (i == 1):
                            expiration = itemstatusExp.text
                            safetyarr.append(expiration)
                        #     print(expiration)
                        #
                        # print("+++++++++++++++")

                if (idx == 6):
                    cityEmpRaw = row.find_all('td', class_='content')

                    for i, itemcityEmp in enumerate(cityEmpRaw):
                        if (i == 0):
                           cityEmp  = itemcityEmp.text
                           safetyarr.append(cityEmp)
                        #    print(cityEmp)
                        #
                        # print("+++++++++++++++")

                if (idx == 7):
                    officeAddressRaw = row.find_all('td', class_='content')

                    for i, itemofficeAdd in enumerate(officeAddressRaw):
                        if (i == 0):
                           officeAdd  = itemofficeAdd.text
                           safetyarr.append(officeAdd)
                        #    print(officeAdd)
                        #
                        # print("+++++++++++++++")

                if (idx == 8):
                    bussinessPhoneRaw = row.find_all('td', class_='content')

                    for i, itembussinessPhone in enumerate(bussinessPhoneRaw):
                        if (i == 0):
                           bussPhone  = itembussinessPhone.text
                           safetyarr.append(bussPhone)
                        #    print(bussPhone)
                        #
                        # print("+++++++++++++++")

                if (idx == 12):
                    bussRaw = row.find_all('td', class_='content')

                    for i, itembuss in enumerate(bussRaw):
                        if (i == 0):
                           business1  = itembuss.text
                           safetyarr.append(business1)
                        #    print(business1)
                        #
                        # print("+++++++++++++++")

                if (idx == 13):
                    doingbussRaw = row.find_all('td', class_='content')

                    for i, itemdoingbuss in enumerate(doingbussRaw):
                        if (i == 0):
                           doingBussiness = itemdoingbuss.text
                           safetyarr.append(doingBussiness)
                        #    print(doingBussiness)
                        #
                        # print("+++++++++++++++")


                if (idx == 16 or idx == 17 or idx == 18):
                    insidearr = []
                    alltd = row.find_all('td', class_='content')
                    alltdcenter = row.find_all('td', class_='centercontent')

                    for item in alltd:
                        output = item.text
                        insidearr.append(output)
                        # print(item.text)

                    for item in alltdcenter:
                        output = item.text
                        insidearr.append(output)
                        # print(item.text)
                    tablearr.append(insidearr)

                    # print(tablearr)
                    # print("+++++++++++")
#
                if (idx == 23 or idx == 24 or idx == 25):
                    alltdrow = row.find_all('td', class_='content')

                    for item in alltdrow:
                        output = item.text
                        endorsementarr.append(output)
                    # print(endorsementarr)
#
#             print(safetyarr)
#             print(tablearr)
#             print(endorsementarr)

            finalarr = []

            for i in safetyarr:
                finalarr.append(i)

            for i in tablearr:
                finalarr.append(i)

            for i in endorsementarr:
                finalarr.append(i)
                
#             print(finalarr)

            cleaned_data = []
            for item in finalarr:
                if isinstance(item, str):
                    cleaned_item = item.replace('\t', '').replace('\xa0', '').replace('\n', '')
                else:
                    cleaned_item = item
                cleaned_data.append(cleaned_item)
                
            allFinalData.append(cleaned_data)

            sleep(2)
            
    sleep(2)

# %%
finalarr

# %%
for i in finalarr:
    print(i)
# Out:
# RIAD                        AAFOUALLAH
#
#
#
#
# 						Date Registered:
#
#
# 					  04/22/2020
#
# Contractor ID:  621840
# Status:  A - ACTIVE
# Expiration:  06/12/2023
# City Employee:   No
# Office Address:  218 MYRTLE AVE #3F   BROOKLYN, NY 11201
# Business Phone:  917-370-2265
#
# Business 1  :  RIAD LLC
#
# Doing Business As:  RA CONSULTING
# ['General Liability', 'UDC-4220091CGL1', 'Yes', 'HISCOX INSURANCE CO', '07/18/2020']
# ["Workers' Compensation", 'KWC1179648', 'Yes', 'AMTRUST INSUR COMP KANSAS', '07/18/2020']
# ['Disability', 'DBL594709', 'Yes', 'SHELTERPOINT LIFE INS CO', '12/31/2020']
# Status:  ACTIVE    Type:  CN - CONSTRUCTION
#
#
#
# Status:  ACTIVE    Type:  DM - DEMOLITION
#
#
#
# Status:  ACTIVE    Type:  CC - CONCRETE

# %%
cleaned_data = []
for item in finalarr:
    if isinstance(item, str):
        cleaned_item = item.replace('\t', '').replace('\xa0', '').replace('\n', '')
    else:
        cleaned_item = item
    cleaned_data.append(cleaned_item)

print(cleaned_data)
# Out:
# ['RIAD                        AAFOUALLAH', 'Date Registered:04/22/2020', 'Contractor ID:621840', 'Status:A - ACTIVE', 'Expiration:06/12/2023', 'City Employee: No', 'Office Address:218 MYRTLE AVE #3F   BROOKLYN, NY 11201', 'Business Phone:917-370-2265', 'Business 1:RIAD LLC', 'Doing Business As:RA CONSULTING', ['General Liability', 'UDC-4220091CGL1', 'Yes', 'HISCOX INSURANCE CO', '07/18/2020'], ["Workers' Compensation", 'KWC1179648', 'Yes', 'AMTRUST INSUR COMP KANSAS', '07/18/2020'], ['Disability', 'DBL594709', 'Yes', 'SHELTERPOINT LIFE INS CO', '12/31/2020'], 'Status:ACTIVEType:CN - CONSTRUCTION', 'Status:ACTIVEType:DM - DEMOLITION', 'Status:ACTIVEType:CC - CONCRETE']

# %%
allFinalData
# Out:
# [['RIAD                        AAFOUALLAH',
#   'Date Registered:04/22/2020',
#   'Contractor ID:621840',
#   'Status:A - ACTIVE',
#   'Expiration:06/12/2023',
#   'City Employee: No',
#   'Office Address:218 MYRTLE AVE #3F   BROOKLYN, NY 11201',
#   'Business Phone:917-370-2265',
#   'Business 1:RIAD LLC',
#   'Doing Business As:RA CONSULTING',
#   ['General Liability',
#    'UDC-4220091CGL1',
#    'Yes',
#    'HISCOX INSURANCE CO',
#    '07/18/2020'],
#   ["Workers' Compensation",
#    'KWC1179648',
#    'Yes',
#    'AMTRUST INSUR COMP KANSAS',
#    '07/18/2020'],
#   ['Disability', 'DBL594709', 'Yes', 'SHELTERPOINT LIFE INS CO', '12/31/2020'],
#   'Status:ACTIVEType:CN - CONSTRUCTION',
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Registered:09/19/2017',
#   'Contractor ID:617984',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:1754 EAST 53RD STREET   BROOKLYN, NY 11234',
#   'Business 1:SPEEDWAY CONSTRUCTION COR',
#   'Business 1:SPEEDWAY CONSTRUCTION COR',
#   ['General Liability',
#    'CONNYF155671194',
#    'Yes',
#    'ILLINOIS UNION INSURANCE',
#    '06/17/2023'],
#   ["Workers' Compensation", 'K2423 419-7', 'Yes', 'NYSIF', '08/02/2023'],
#   ['Disability',
#    'DBL511041',
#    'Yes',
#    'SHELTERPOINT LIFE INSURAN',
#    '08/01/2023'],
#   'Status:ACTIVEType:CN - CONSTRUCTION',
#   'Status:ACTIVEType:CC - CONCRETE',
#   'Status:ACTIVEType:DM - DEMOLITION'],
#  ['Date Issued:06/25/2010',
#   'Contractor ID:605070',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:1839 BOGART AVENUE   BRONX, NY 10462',
#   'Business 1:SLR CONSTRUCTION CO',
#   'Business 1:SLR CONSTRUCTION CO',
#   ['General Liability',
#    'LO36004808',
#    'Yes',
#    'ATLANTIC CASUALTY INS CO',
#    '01/30/2012'],
#   ["Workers' Compensation", 'UB1A02754011', 'Yes', 'TRAVELERS', '04/27/2012'],
#   ['Disability', 'D340762', 'Yes', '1ST REHAB LIFE INS CO AME', '05/13/2012'],
#   'None'],
#  ['LUIS                        AANTUNES',
#   'Date Registered:04/04/2016',
#   'Contractor ID:615589',
#   'Status:A - ACTIVE',
#   'Expiration:04/04/2025',
#   'City Employee: No',
#   'Office Address:9 UNION AVENUE   RONKONKOMA, NY 11779',
#   'Business Phone:631-467-4180',
#   'Business 1:C & L CONCRETE CORP',
#   ["Workers' Compensation", 'G2224 546-8', 'Yes', 'NYSIF', '01/01/2023'],
#   ['Disability',
#    'D99909-000',
#    'Yes',
#    'STANDARD SECURITY LIFE NY',
#    '01/03/2023'],
#   ['\xa0']],
#  ['BROYN                       AARON',
#   'Date Registered:07/12/2022',
#   'Contractor ID:624039',
#   'Status:A - ACTIVE',
#   'Expiration:07/12/2025',
#   'City Employee: No',
#   'Office Address:11 SALISBURY AVE   GARDEN CITY, NJ 11530',
#   'Business Phone:646-655-7476',
#   'Business 1:SIERRA CONST MGNT CORP',
#   ["Workers' Compensation",
#    '001TE80675',
#    'Yes',
#    'TRAVELERS INS',
#    '02/02/2023'],
#   ['Disability', 'DBL657459', 'Yes', 'SHELTERPOINT', '02/01/2023'],
#   ['\xa0'],
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Issued:11/07/2016',
#   'Contractor ID:616569',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:15 CHARLES PLACE   HUNTINGTON STATION, NY 11746',
#   'Business 1:DELTA GENERAL CONSTRUCTIO',
#   'Business 1:DELTA GENERAL CONSTRUCTIO',
#   ['General Liability',
#    '8SA-4150988',
#    'Yes',
#    'UNITED SPECIALTY INS',
#    '10/24/2018'],
#   ["Workers' Compensation", 'I2401 127-2', 'Yes', 'NYSIF', '02/20/2019'],
#   ['Disability', 'DBL495255', 'Yes', 'SHELTERPOINT LIFE INS CO', '10/24/2018'],
#   'None'],
#  ['Date Issued:10/09/2020',
#   'Contractor ID:622234',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:86-20 107TH AVENUE   OZONE PARK, NY 11417',
#   'Business 1:BROTHERS CONSTRUCTION GRO',
#   'Business 1:BROTHERS CONSTRUCTION GRO',
#   ['General Liability',
#    'SKP-2011836-12',
#    'Yes',
#    'AMERCAN EUROPEAN INS',
#    '10/01/2023'],
#   ["Workers' Compensation", 'Q2524-668-7', 'Yes', 'NYSIF', '10/02/2023'],
#   ['Disability',
#    'DBL 623257',
#    'Yes',
#    'SHELTERPOINT LIFE INS CO',
#    '10/01/2023'],
#   'None'],
#  ['Date Issued:11/14/2019',
#   'Contractor ID:621326',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:204-09 JAMAICA AVENUE   JAMAICA, NY 11423',
#   'Business 1:NY LIMITS CONTRACTING COR',
#   'Business 1:NY LIMITS CONTRACTING COR',
#   ['General Liability',
#    'BND0002961-01',
#    'Yes',
#    'ACCEPTANCE INDEMNITY INS',
#    '10/03/2023'],
#   ["Workers' Compensation", 'NYWC377567', 'Yes', 'NYSIF', '12/31/2023'],
#   ['Disability', 'DBL565043', 'Yes', 'SHELTERPOINT LIFE INS.CO', '09/30/2023'],
#   'None'],
#  ['Date Issued:10/17/2019',
#   'Contractor ID:621184',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:101-06 67TH DRIVE APT 3H   FOREST HILLS, NY 11375',
#   'Business 1:ABA QUALITY CONSTRUCTION',
#   'Business 1:ABA QUALITY CONSTRUCTION',
#   ['General Liability',
#    'L302001346 0',
#    'Yes',
#    'ATLANTIC CASUALTY INSUR',
#    '09/07/2023'],
#   ["Workers' Compensation", 'Q2486 212-0', 'Yes', 'NYSIF', '09/28/2023'],
#   ['Disability',
#    'DBL564886',
#    'Yes',
#    'SHELTERPOINT LIFE INS COM',
#    '09/26/2023'],
#   'None'],
#  ['Date Issued:01/28/2011',
#   'Contractor ID:606326',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:2130 BROADWAY #204   NEW YORK, NY 10023',
#   'Business 1:718 HEIGHTS LLC',
#   'Business 1:718 HEIGHTS LLC',
#   ['General Liability',
#    'WPP1471375-01',
#    'Yes',
#    'WESCO INSURANCE COMPANY',
#    '06/20/2018'],
#   ["Workers' Compensation", 'G1222 179-2', 'Yes', 'NYSIF', '03/29/2018'],
#   ['Disability',
#    'DBL244658',
#    'Yes',
#    'SHELTERPOINT LIFE INS. CO',
#    '12/27/2017'],
#   'None'],
#  ['Date Issued:11/08/2018',
#   'Contractor ID:619819',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:25 W 39TH STREET   NEW YORK, NY 10018',
#   'Business 1:HKO GROUP LLC',
#   'Business 1:HKO GROUP LLC',
#   ['General Liability',
#    '5051031119',
#    'Yes',
#    'ALLIED WORLD NATIONAL ASS',
#    '08/01/2020'],
#   ["Workers' Compensation", 'L2451331-1', 'Yes', 'NYSIF', '08/16/2020'],
#   ['Disability', '82751-02', 'Yes', 'STANDARD SECURITY LIFE NY', '11/18/2020'],
#   'None'],
#  ['Date Issued:04/19/2019',
#   'Contractor ID:620464',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:22-04 RYAN STREET   WHITESTONE, NY 11357',
#   'Business 1:MAKABAD. CORP',
#   'Business 1:MAKABAD. CORP',
#   ['General Liability',
#    '5061038700',
#    'Yes',
#    'ALLIED WORLD SURPLUS',
#    '02/19/2024'],
#   ["Workers' Compensation", 'Q2466 490-6', 'Yes', 'NYSIF', '03/02/2024'],
#   ['Disability', 'DBO3987941.1', 'Yes', 'AMGUARD INSURANCE CO', '04/08/2023'],
#   'None'],
#  ['Date Issued:10/25/2010',
#   'Contractor ID:605822',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:610 WEST 138TH STREET 4TH FL   NY, NY 10012',
#   'Business 1:BUILDING EQUITY LLC',
#   'Business 1:BUILDING EQUITY LLC',
#   ['General Liability',
#    'VBA564915',
#    'Yes',
#    'COVINGTON SPECIALTY INS C',
#    '09/27/2018'],
#   ["Workers' Compensation", 'M2397 186-4', 'Yes', 'NYSIF', '08/23/2018'],
#   ['Disability',
#    'DBL 347911',
#    'Yes',
#    'SHELTERPOINT LIFE INS COM',
#    '10/13/2018'],
#   'None'],
#  ['MICHAEL                     ABATEMARCO',
#   'Date Registered:07/09/2020',
#   'Contractor ID:616482',
#   'Status:E - EXPIRED',
#   'Expiration:12/31/2020',
#   'City Employee: No',
#   'Office Address:142 RALPH AVENUE UNIT B   COPIAGUE, NY 11726',
#   'Business Phone:631-789-3401',
#   'Business 1:CONSTRUCTION WORKS GROUP',
#   ["Workers' Compensation", 'H2388 855-5', 'Yes', 'NYSIF', '05/06/2020'],
#   ['Disability', 'L81586-000', 'Yes', 'STANDARD SECURITY LIFE', '04/24/2020'],
#   ['\xa0'],
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Issued:12/06/2022',
#   'Contractor ID:624450',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:66-64 THORNTON PLACE   REGO PARK, NY 11374',
#   'Business 1:ALMA DEVELOPERS LLC',
#   'Business 1:ALMA DEVELOPERS LLC',
#   ['General Liability',
#    '92-C5-K802-7',
#    'Yes',
#    'STATE FARM FIRE & CASUAL',
#    '06/15/2023'],
#   ["Workers' Compensation",
#    'N9WC909348',
#    'Yes',
#    'BERKSHIRE HATHAWAY DIR IN',
#    '12/01/2023'],
#   ['Disability',
#    'L93527-000',
#    'Yes',
#    'STANDARD SEC LIFE INS CO',
#    '11/30/2023'],
#   'None'],
#  ['SLAVIK                      ABAYEV',
#   'Date Registered:12/02/2011',
#   'Contractor ID:608040',
#   'Status:E - EXPIRED',
#   'Expiration:12/02/2014',
#   'City Employee: No',
#   'Office Address:14 FLORDIA AVENUE   STATEN ISLAND, NY 10305',
#   'Business Phone:917-567-9000',
#   'Business 1:NABA ENTERPRISE INC',
#   ["Workers' Compensation",
#    'WC051758506',
#    'Yes',
#    'COMMERCE AND INDUSTRY INS',
#    '10/30/2013'],
#   ['Disability',
#    'DBL368633',
#    'Yes',
#    'FIRST REHAB LIFE INS CO A',
#    '11/29/2013'],
#   ['\xa0'],
#   'Status:ACTIVEType:CC - CONCRETE',
#   'Status:ACTIVEType:DM - DEMOLITION'],
#  ['Date Registered:08/16/2013',
#   'Contractor ID:610259',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:14 FLORIDA AVENUE   STATEN ISLAND, NY 10305',
#   'Business 1:ABBA BUILDERS, INC',
#   'Business 1:ABBA BUILDERS, INC',
#   ['General Liability',
#    'CL00286775',
#    'Yes',
#    'CENTURY SURETY COMP',
#    '10/25/2020'],
#   ["Workers' Compensation", 'V 2248 623 7', 'Yes', 'NYSIF', '12/31/2020'],
#   ['Disability',
#    'DBL 401635',
#    'Yes',
#    'SHELTERPOINT LIFE INS CO',
#    '01/14/2021'],
#   'Status:ACTIVEType:CN - CONSTRUCTION',
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Issued:10/19/2016',
#   'Contractor ID:616499',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:381 QUAKER RIDGE ROAD   NEW ROCHELLE, NY 10804',
#   'Business 1:GREAT METLA CONTRACTING I',
#   'Business 1:GREAT METLA CONTRACTING I',
#   ['General Liability',
#    'NPP8889148',
#    'Yes',
#    'WESTERN WORLD INS. COMPAN',
#    '07/21/2023'],
#   ["Workers' Compensation",
#    '81-3860696',
#    'Yes',
#    'STATEFARM FIRE & CASUALTY',
#    '07/22/2023'],
#   ['Disability',
#    'L82693-000',
#    'Yes',
#    'STANDARD SEC LIFE INS CO',
#    '08/10/2023'],
#   'None'],
#  ['Date Issued:04/25/2014',
#   'Contractor ID:612365',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:381 QUAKER RIDGE ROAD   NEW ROCHELLE, NY 10804',
#   'Business 1:MBC REST & WATERPROOFING',
#   'Business 1:MBC REST & WATERPROOFING',
#   ['General Liability',
#    'AGL004957-02',
#    'Yes',
#    'ARCH SPECIALTY INS',
#    '10/04/2016'],
#   ["Workers' Compensation",
#    'WWC00283878',
#    'Yes',
#    'WESCO INSURANCE COMPANY',
#    '07/21/2016'],
#   ['Disability', 'L78343-000', 'Yes', 'STANDARD SECURITY LIFE', '10/29/2016'],
#   'None'],
#  ['Date Issued:03/27/2019',
#   'Contractor ID:620369',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:2762 W 15TH STREET   BROOKLYN, NY 11224',
#   'Business 1:RITZ PUMP SERVICE INC',
#   'Business 1:RITZ PUMP SERVICE INC',
#   ['General Liability', '', 'No', '', ''],
#   ["Workers' Compensation", 'K2453 557 7', 'Yes', 'NYSIF', '09/12/2022'],
#   ['Disability', 'DBL540444', 'Yes', 'SHELTERPOINT LIFE INS CO', '09/11/2022'],
#   'None'],
#  ['Date Issued:07/21/2009',
#   'Contractor ID:603102',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:1833  NEW HYDE PARK ROAD   NEW HYDE PARK, NY 11040',
#   'Business 1:LT MECHANICAL & G CONST C',
#   'Business 1:LT MECHANICAL & G CONST C',
#   ['General Liability', '10129', 'Yes', 'NOVA CASUALTY', '07/15/2010'],
#   ["Workers' Compensation",
#    '003WK03223',
#    'Yes',
#    'SPARTA INS CO',
#    '07/14/2010'],
#   ['Disability', '323869', 'Yes', '1SR REHAB LIFE', '07/14/2010'],
#   'None'],
#  ['Date Issued:06/21/2013',
#   'Contractor ID:610938',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:1602 EAST 55TH STREET 1ST FL   BROOKLYN, NY 11234',
#   'Business 1:KINGS WORLD CONSTRUCTION',
#   'Business 1:KINGS WORLD CONSTRUCTION',
#   ['General Liability',
#    'ART0014259',
#    'Yes',
#    'ARCH SPECIALTY INS CO',
#    '03/07/2018'],
#   ["Workers' Compensation", 'K2333 439-4', 'Yes', 'NYSIF', '05/01/2018'],
#   ['Disability', 'DBL410658', 'Yes', 'SHELTERPOINT LIFE INS CO', '06/20/2018'],
#   'None'],
#  ['Date Issued:08/12/2011',
#   'Contractor ID:607458',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:2125 78 ST   BKLYN, NY 11214',
#   'Business 1:OK-1 CONSTRUCTION CORP',
#   'Business 1:OK-1 CONSTRUCTION CORP',
#   ['General Liability',
#    '756B000517',
#    'Yes',
#    'BURLINGTON INS CO',
#    '06/29/2013'],
#   ["Workers' Compensation", 'K21524954', 'Yes', 'NYSIF', '04/03/2013'],
#   ['Disability', '9989040000', 'Yes', 'GUARDIAN LIFE INS CO', '06/28/2013'],
#   'None'],
#  ['Date Issued:03/10/2016',
#   'Contractor ID:615470',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:1311 BRONX RIVER AVENUE   BRONX, NY 10472',
#   'Business 1:RED HILL CONSTRUCTION INC',
#   'Business 1:RED HILL CONSTRUCTION INC',
#   ['General Liability',
#    'ODMEJ-X',
#    'Yes',
#    'WESTERN WORLD INS CO',
#    '05/02/2019'],
#   ["Workers' Compensation", 'X2383 365-0', 'Yes', 'NYSIF', '03/04/2019'],
#   ['Disability',
#    'DBL483309',
#    'Yes',
#    'SHELTERPOINT LIFE INS. CO',
#    '03/03/2019'],
#   'None'],
#  ['Date Issued:11/08/2017',
#   'Contractor ID:618207',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:251 N REGENT STREET   PORT CHESTER, NY 10573',
#   'Business 1:LIBERTY GENERAL CONTRACTI',
#   'Business 1:LIBERTY GENERAL CONTRACTI',
#   ['General Liability',
#    'NPP8889058',
#    'Yes',
#    'WESTERN WORLD INSURANCE',
#    '06/12/2023'],
#   ["Workers' Compensation",
#    '98-CR-D819-3',
#    'Yes',
#    'STATE FARM FIRE CASUALTY',
#    '06/11/2023'],
#   ['Disability',
#    'L84948-000',
#    'Yes',
#    'STANDARD SEC LIFE INS CO',
#    '04/03/2024'],
#   'None'],
#  ['Date Registered:02/11/2009',
#   'Contractor ID:015409',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:430 CONEY ISLAND AVE   BROOKLYN, NY 11218',
#   'Business 1:ABASI CONSTRUCTION CORP',
#   'Business 1:ABASI CONSTRUCTION CORP',
#   ['General Liability',
#    'I6803346N983ACJ',
#    'Yes',
#    'TRAVELERS CASUALTY INS CO',
#    '03/28/2011'],
#   ["Workers' Compensation",
#    'WC006755989',
#    'Yes',
#    'NATIONAL UNION FIRE PA',
#    '04/01/2011'],
#   ['Disability', 'DBL96343', 'Yes', 'FIRST REHABILITATION LIFE', '03/22/2011'],
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Issued:01/25/2011',
#   'Contractor ID:606302',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:430 CONEY ISLAND AVENUE   BROOKLYN, NY 11218',
#   'Business 1:ABBASI GENERAL CONSTRUCTI',
#   'Business 1:ABBASI GENERAL CONSTRUCTI',
#   ['General Liability',
#    '01PGLP003165',
#    'Yes',
#    'ATEGRITY SPECIALTY INS CO',
#    '01/31/2024'],
#   ["Workers' Compensation", 'K2129 116-6', 'Yes', 'NYSIF', '01/31/2024'],
#   ['Disability',
#    'DBL352721',
#    'Yes',
#    'SHELTERPOINT LIFE INS. CO',
#    '01/23/2024'],
#   'None'],
#  ['Date Issued:01/27/2012',
#   'Contractor ID:608295',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:1564 WEST 9TH STREET   BROOKLYN, NY 11204',
#   'Business 1:A&G DESIGN CORPORATION',
#   'Business 1:A&G DESIGN CORPORATION',
#   ['General Liability',
#    'BDG0098466 08',
#    'Yes',
#    'MAXUM IDEMNITY INS CO',
#    '10/02/2023'],
#   ["Workers' Compensation",
#    'N9WC873076',
#    'Yes',
#    'WELLFLEET NY INSURANCE CO',
#    '02/03/2024'],
#   ['Disability', 'D97193 000', 'Yes', 'STD SEC LIFE INS COM NY', '01/26/2024'],
#   'None'],
#  ['Date Issued:01/25/2019',
#   'Contractor ID:620102',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:2961 HARDING AVENUE   BRONX, NY 10465',
#   'Business 1:WIT VENTURES LLC',
#   'Business 1:WIT VENTURES LLC',
#   ['General Liability', '', 'No', '', ''],
#   ["Workers' Compensation",
#    'N9WC848750',
#    'Yes',
#    'BERKSHIRE HATHAWAY DIRECT',
#    '01/18/2024'],
#   ['Disability', 'DBL 7197 79-2', 'Yes', 'NYSIF', '12/18/2023'],
#   'None'],
#  ['Date Issued:11/03/2008',
#   'Contractor ID:018479',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:1174 COMMERCE AVENUE   BRONX, NY 10462',
#   'Business 1:TECHNICAL CONSTR SERV.INC',
#   'Business 1:TECHNICAL CONSTR SERV.INC',
#   ['General Liability',
#    '1000025004141',
#    'Yes',
#    'STARR INDEMNITY&LIABILITY',
#    '05/08/2016'],
#   ["Workers' Compensation",
#    '004472400205',
#    'Yes',
#    'STARR INSURANCE CO',
#    '05/08/2016'],
#   ['Disability', 'LNY 643525', 'Yes', 'HARTFORD LIFE INSURANCE', '03/31/2016'],
#   'None'],
#  ['Date Issued:08/22/2008',
#   'Contractor ID:027667',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:4 LAKESIDE DRIVE EAST   FORKED RIVER, NJ 08731',
#   'Business 1:DCM OF NEW YORK LLC',
#   'Business 1:DCM OF NEW YORK LLC',
#   ['General Liability', '129248-3', 'Yes', 'ALL RISKS LIMITED', '12/01/2014'],
#   ["Workers' Compensation", 'W 2315 443 8', 'Yes', 'NYSIF', '11/23/2014'],
#   ['Disability', 'DBL5244190', 'Yes', 'NYS INSURANCE FUND', '05/22/2015'],
#   'None'],
#  ['Date Issued:11/06/2008',
#   'Contractor ID:601542',
#   'Status:A - ACTIVE',
#   'Home Improvement Contractor:0897039',
#   'City Employee: No',
#   '',
#   'Business 1:SALAB CONSTRUCTION CORP',
#   [],
#   ['General Liability',
#    'ISCO1000000028',
#    'Yes',
#    'SUTTON SPECIALTY INS. CO',
#    '03/24/2024'],
#   ["Workers' Compensation",
#    'K1134 212-8',
#    'Yes',
#    'NEW YORK STATE INS. FUND',
#    '12/10/2023'],
#   'None'],
#  ['Date Issued:05/27/2021',
#   'Contractor ID:622887',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:10 HACKENSACK AVE   WEEHAWKEN, NJ 07086',
#   'Business 1:EMERALD SERVICES CORP',
#   'Business 1:EMERALD SERVICES CORP',
#   [],
#   ['General Liability',
#    'BKS61325767',
#    'Yes',
#    'OHIO SECURITY INS COM',
#    '05/29/2023'],
#   ["Workers' Compensation",
#    'WC 96520 00',
#    'Yes',
#    'SIRIUS AMERICA INS COMPAN',
#    '05/04/2023'],
#   'None'],
#  ['Date Issued:02/02/2015',
#   'Contractor ID:613613',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:1015 WEST JERICHO TURNPIKE   SMITHTOWN, NY 11787',
#   'Business 1:GAPPSI INC',
#   'Business 1:GAPPSI INC',
#   ['General Liability',
#    'SPP49880M',
#    'Yes',
#    'WORCESTER INSURANCE CO',
#    '03/08/2015'],
#   ["Workers' Compensation", 'G2332038-5', 'Yes', 'NYSIF', '03/10/2015'],
#   ['Disability',
#    'R09438-000',
#    'Yes',
#    'STANDARD SECURITY LIFE IN',
#    '01/05/2016'],
#   'None'],
#  ['Date Registered:03/09/2012',
#   'Contractor ID:607540',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:45-50 30TH ST 7TH FLOOR   LONG ISLAND CITY, NY 11101',
#   'Business 1:MERIDIAN DESIGN & CONSTRU',
#   'Business 1:MERIDIAN DESIGN & CONSTRU',
#   ['General Liability',
#    '00000018945',
#    'Yes',
#    'UNDERWRITERS AT LLOYDS',
#    '02/13/2014'],
#   ["Workers' Compensation", 'L 2157 0833', 'Yes', 'NYSIF', '02/13/2014'],
#   ['Disability', 'D6093679', 'Yes', 'NYSIF', '02/13/2014'],
#   'None'],
#  ['Date Issued:03/29/2018',
#   'Contractor ID:618825',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:195-03 50TH AVENUE   FRESH MEADOWS, NY 11365',
#   'Business 1:WAMO BUILDING LLC',
#   'Business 1:WAMO BUILDING LLC',
#   ['General Liability',
#    'UDC-2193265-18',
#    'Yes',
#    'HISCOX INSURANCE COMPANY',
#    '03/06/2019'],
#   ["Workers' Compensation", 'Q2439 535-2', 'Yes', 'NYSIF', '03/21/2019'],
#   ['Disability', 'DBL 7041 69-3', 'Yes', 'NYSIF', '03/09/2019'],
#   'None'],
#  ['Date Registered:08/10/2020',
#   'Contractor ID:622051',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:23 GRISSOM AVE   STATEN ISLAND, NY 10314',
#   'Business 1:MDA ASSOCIATES NY INC',
#   'Business 1:MDA ASSOCIATES NY INC',
#   ['General Liability',
#    'PAV0161066',
#    'Yes',
#    'PENN-AMERICA GROUP',
#    '12/10/2020'],
#   ["Workers' Compensation", 'V2460 053-8', 'Yes', 'NYSIF', '12/20/2020'],
#   ['Disability',
#    'Z06593-000',
#    'Yes',
#    'STANDARD SEC LIFE INS COM',
#    '05/31/2021'],
#   'Status:ACTIVEType:CN - CONSTRUCTION',
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Issued:05/12/2010',
#   'Contractor ID:604731',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:149-12 61ST ROAD   FLUSHING, NY 11367',
#   'Business 1:OMAR CONTRACTING CORP',
#   'Business 1:OMAR CONTRACTING CORP',
#   ['General Liability',
#    'CLC7000235100',
#    'Yes',
#    'TOWER INSURANCE CO',
#    '05/10/2012'],
#   ["Workers' Compensation",
#    'OMWC207226',
#    'Yes',
#    'NORGUARD INSURANCE',
#    '02/12/2012'],
#   ['Disability',
#    'DBL333756',
#    'Yes',
#    '1ST REHAB LIFE INS CO AME',
#    '02/09/2012'],
#   'None'],
#  ['Date Issued:09/03/2020',
#   'Contractor ID:622127',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:271 VAN SICLEN AVE.APT 1R   BROOKLYN, NY 11207',
#   'Business 1:TWIN RENO CORP',
#   'Business 1:TWIN RENO CORP',
#   ['General Liability',
#    'AES1199878 00',
#    'Yes',
#    'ASSOCIATED INDUSTRIES INS',
#    '07/28/2021'],
#   ["Workers' Compensation", 'K2519 111-5', 'Yes', 'NYSIF', '07/24/2021'],
#   ['Disability',
#    'Z07513-000',
#    'Yes',
#    'STANDARD SEC LIFE INS COM',
#    '08/11/2021'],
#   'None'],
#  ['Date Issued:01/11/2013',
#   'Contractor ID:610091',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:31 COZINE ROAD   CENTER MORICHES, NY 11934',
#   'Business 1:ROSE CARPENTRY INC',
#   'Business 1:ROSE CARPENTRY INC',
#   ['General Liability',
#    'WS263057',
#    'Yes',
#    'NORTHFILED INSURANCE COMP',
#    '02/25/2017'],
#   ["Workers' Compensation",
#    'WWC 3224872',
#    'Yes',
#    'WESCO INSURANCE COMPANY',
#    '09/01/2017'],
#   ['Disability', 'DBL352110', 'Yes', 'SHELTERPOINT LIFE INS CO', '01/08/2017'],
#   'None'],
#  ['Date Issued:07/14/2010',
#   'Contractor ID:605180',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:79-20 153RD AVENUE   HOWARD BEACH, NY 11414',
#   'Business 1:DREAMLAND CONSTRUCTION IN',
#   'Business 1:DREAMLAND CONSTRUCTION IN',
#   ['General Liability',
#    '98-CR-D601-1',
#    'Yes',
#    'STATE FARM FIRE & CASUAL',
#    '06/04/2023'],
#   ["Workers' Compensation",
#    'DRWC315986',
#    'Yes',
#    'NORGUARD INSURANCE COMPAN',
#    '05/15/2023'],
#   ['Disability', 'D599 858', 'Yes', 'SHELTERPOINT LIFE AND INS', '07/04/2023'],
#   'None'],
#  ['Date Issued:07/30/2019',
#   'Contractor ID:620891',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:259-23 148TH DRIVE   ROSEDALE, NY 11422',
#   'Business 1:AIR ROUND CONSTRUCTION CO',
#   'Business 1:AIR ROUND CONSTRUCTION CO',
#   ['General Liability',
#    'CL00289537',
#    'Yes',
#    'ATLANTIC CASUALTY INS CO',
#    '07/24/2020'],
#   ["Workers' Compensation",
#    '98-CD-E175-6',
#    'Yes',
#    'STATE FARM & CASUALTY CO',
#    '01/25/2020'],
#   ['Disability',
#    'DBL 559943',
#    'Yes',
#    'SHELTERPOINT LIFE INS CO',
#    '07/09/2020'],
#   'None'],
#  ['Date Issued:10/20/2020',
#   'Contractor ID:622268',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:249-20 CANEY ROAD   ROSEDALE, NY 11422',
#   'Business 1:BK IRON WORKS CORP',
#   'Business 1:BK IRON WORKS CORP',
#   ['General Liability',
#    'RNY055252018-03',
#    'Yes',
#    'ROCKINGHAM INSURANCE COM',
#    '05/25/2022'],
#   ["Workers' Compensation",
#    'K2499 073-1',
#    'Yes',
#    'NYS INSURANCE FUND',
#    '01/25/2023'],
#   ['Disability',
#    'L89729-000',
#    'Yes',
#    'STD SECURITY LIFE INS NY',
#    '04/11/2023'],
#   'None'],
#  ['Date Issued:09/18/2019',
#   'Contractor ID:621067',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:807 BERGEN STREET   BROOKLYN, NY 11238',
#   'Business 1:MOHAB ELECTRICAL CONTRACT',
#   'Business 1:MOHAB ELECTRICAL CONTRACT',
#   ['General Liability',
#    'CPP 5220445',
#    'Yes',
#    'REPUBLIC-FRANKLIN INS CO',
#    '01/11/2024'],
#   ["Workers' Compensation",
#    'KWC1302245',
#    'Yes',
#    'AMTRUST INSURANCE COMPANY',
#    '10/21/2023'],
#   ['Disability', 'DBL171123', 'Yes', 'SHELTERPOINT LIFE INS CO', '10/15/2023'],
#   'None'],
#  ['Date Registered:05/17/2012',
#   'Contractor ID:608770',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:2545 YOUNG AVENUE   BRONX, NY 10469',
#   'Business 1:ZANDERS D. CORP',
#   'Business 1:ZANDERS D. CORP',
#   ['General Liability',
#    'MPU7887J',
#    'Yes',
#    'MAIN STREET AMERICA ASSUR',
#    '03/06/2016'],
#   ["Workers' Compensation",
#    'WCU7887J',
#    'Yes',
#    'NGM INSURANCE COMPANY',
#    '03/06/2016'],
#   ['Disability',
#    'L9043-000',
#    'Yes',
#    'STANDARD SECURITY LIFE IN',
#    '03/06/2016'],
#   'Status:ACTIVEType:CN - CONSTRUCTION',
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Issued:10/22/2020',
#   'Contractor ID:622272',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:2221 BATH AVENUE   BROOKLYN, NY 11214',
#   'Business 1:HIGH SKY CONSTRUCTION INC',
#   'Business 1:HIGH SKY CONSTRUCTION INC',
#   ['General Liability',
#    'BP3169532Q2021',
#    'Yes',
#    'ILLINOIS UNION INS. COMP',
#    '08/09/2023'],
#   ["Workers' Compensation",
#    'EIG4792963-00',
#    'Yes',
#    'EMPLOYERS ASSURANCE COMPA',
#    '08/08/2023'],
#   ['Disability',
#    'L90618-000',
#    'Yes',
#    'STD SECURITY LIFE INS NY',
#    '08/16/2023'],
#   'None'],
#  ['SAAD                        ABDULLA',
#   'Date Registered:10/13/2011',
#   'Contractor ID:600705',
#   'Status:E - EXPIRED',
#   'Expiration:10/13/2014',
#   'City Employee: No',
#   'Office Address:168 LAUREL AVE   NORTHPORT, NY 11768',
#   'Business Phone:631-261-0744',
#   'Business 1:FALCONS NY INC',
#   ["Workers' Compensation", 'WC019396575', 'Yes', 'CHARTIS', '11/21/2013'],
#   ['Disability', '5368179-001', 'Yes', 'AMGUARD INS CO', '11/21/2013'],
#   ['\xa0'],
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Issued:05/11/2020',
#   'Contractor ID:612953',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:59B REMINGTON BLVD   RONKONKOMA, NY 11779',
#   'Business 1:DOVER USA, INC',
#   'Business 1:DOVER USA, INC',
#   ['General Liability',
#    'L068022073-0',
#    'Yes',
#    'ATLANTIC CASUALTY',
#    '03/23/2020'],
#   ["Workers' Compensation",
#    '92-CK-X363-2',
#    'Yes',
#    'STATE FARM FIRE AND CASUA',
#    '05/17/2020'],
#   ['Disability', 'DBL529776', 'Yes', 'SHELTERPOINT LIFE INS CO', '03/22/2020'],
#   'None'],
#  ['Date Issued:01/12/2017',
#   'Contractor ID:616807',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:1425 PARKER STREET   BRONX, NY 10462',
#   'Business 1:SENEEN INTERNATIONAL LLC',
#   'Business 1:SENEEN INTERNATIONAL LLC',
#   ['General Liability', 'CP 5018188', 'Yes', 'KINGSTONE', '12/22/2017'],
#   ["Workers' Compensation", 'X2406 205-1', 'Yes', 'NYSIF', '12/28/2017'],
#   ['Disability', 'DBL498927', 'Yes', 'SHELTERPONT LIFE INS CO', '12/27/2017'],
#   'None'],
#  ['ZAFAR                       ABDULLAEV',
#   'Date Registered:05/10/2019',
#   'Contractor ID:620549',
#   'Status:A - ACTIVE',
#   'Expiration:05/10/2025',
#   'City Employee: No',
#   'Office Address:62-10 99TH STREET APT 4C   REGO PARK, NY 11374',
#   'Business Phone:347-430-1473',
#   'Business 1:GREAT TIM CONSTRUCTION IN',
#   ["Workers' Compensation", 'Q2434 216-4', 'Yes', 'NYSIF', '01/01/2023'],
#   ['Disability', 'DBL555958', 'Yes', 'SHELTERPOINT LIFE INS CO', '12/26/2022'],
#   ['\xa0']],
#  ['ZAFAR                       ABDULLAEV',
#   'Date Registered:05/03/2023',
#   'Contractor ID:624784',
#   'Status:H - ON HOLD',
#   'Expiration:05/03/2026',
#   'City Employee: No',
#   'Office Address:369 LEXINGTON AVE STE#372   NEW YORK, NY 10017',
#   'Business Phone:347-430-1473',
#   'Business 1:GT & K CONSTRUCTION INC',
#   ["Workers' Compensation", 'L2583 135-5', 'Yes', 'NYSIF', '01/04/2024'],
#   ['Disability',
#    'DBL683511',
#    'Yes',
#    'SHELTERPOINT LIFE INS COM',
#    '01/17/2024'],
#   ['\xa0'],
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['Date Issued:11/05/2008',
#   'Contractor ID:039843',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:8666 18TH AVE   BROOKLYN, NY 11214',
#   'Business 1:ATCO RESTORATION INC',
#   'Business 1:ATCO RESTORATION INC',
#   ['General Liability',
#    'USA4133264',
#    'Yes',
#    'UNITED SPECIALTY INS CO',
#    '11/10/2018'],
#   ["Workers' Compensation",
#    'K 2004 721-3',
#    'Yes',
#    'NEW YORK STATE INS FUND',
#    '11/14/2018'],
#   ['Disability',
#    'L85139-000',
#    'Yes',
#    'STNDRD LIFE INS CO OF NY',
#    '12/03/2018'],
#   'None'],
#  ['Date Registered:10/19/2012',
#   'Contractor ID:026481',
#   'Status:A - ACTIVE',
#   'City Employee: Yes',
#   'Office Address:38 ALBOURNE AVENUE EAST   STATEN ISLAND, NY 10312',
#   "Business 1:PHIL'S HOME IMPROVEMENT L",
#   "Business 1:PHIL'S HOME IMPROVEMENT L",
#   ['General Liability',
#    'PAV0255567',
#    'Yes',
#    'PENN STAR INSURANC CO',
#    '07/29/2022'],
#   ["Workers' Compensation", 'V 1197 903 6', 'Yes', 'NYSIF', '02/02/2023'],
#   ['Disability', '67234 00', 'Yes', 'STANDARD SECURITY LIFE IN', '08/01/2022'],
#   'Status:ACTIVEType:CN - CONSTRUCTION',
#   'Status:ACTIVEType:DM - DEMOLITION'],
#  ['Date Issued:01/07/2011',
#   'Contractor ID:606220',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:92 SAINT NICHOLAS AVE   NEW YORK, NY 10026',
#   'Business 1:MASTER BUILDERS HOME IMPR',
#   'Business 1:MASTER BUILDERS HOME IMPR',
#   ['General Liability', '', 'Yes', 'PCIC', '10/25/2011'],
#   ["Workers' Compensation", '', 'Yes', 'NORGUARD INS CO', '10/25/2011'],
#   ['Disability', '', 'Yes', 'STANDARD SECURITY LIFE', '01/04/2012'],
#   'None'],
#  ['Date Issued:05/11/2020',
#   'Contractor ID:620528',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:218 E 125TH STREET   NEW YORK, NY 10035',
#   'Business 1:218 MANAGEMENT CORPORATI*',
#   'Business 1:218 MANAGEMENT CORPORATI*',
#   ['General Liability', '', 'No', '', ''],
#   ["Workers' Compensation",
#    'UB-2N260483-22',
#    'Yes',
#    'THE PHOENIX INS COMP',
#    '02/06/2023'],
#   ['Disability', 'R22298-000', 'Yes', 'STANDARD SECURITY LIFE', '03/16/2023'],
#   'None'],
#  ['Date Issued:07/21/2008',
#   'Contractor ID:005601',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:36 STRATHMORE ROAD   GREAT NECK, NY 11023',
#   'Business 1:NICHIBI ORGANIZATION INC',
#   'Business 1:NICHIBI ORGANIZATION INC',
#   [],
#   ['General Liability',
#    'ART3000352130',
#    'Yes',
#    'UTICA FIRST INSURANCE',
#    '05/03/2024'],
#   ["Workers' Compensation",
#    'WWC3648685',
#    'Yes',
#    'WESCO INSURANCE COMPANY',
#    '05/03/2024'],
#   'None'],
#  ['Date Issued:07/20/2022',
#   'Contractor ID:624074',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:725 AVENUE OF THE AMERICAS   NEW YORK, NY 10010',
#   'Business 1:CHELSEA GR PRO MGMT LLC',
#   'Business 1:CHELSEA GR PRO MGMT LLC',
#   ['General Liability',
#    'NPP8419844',
#    'Yes',
#    'WESTERN WORLD INS CO',
#    '04/06/2024'],
#   ["Workers' Compensation",
#    'EIG4982415',
#    'Yes',
#    'EMPLOYERS LIABILITY INS',
#    '04/07/2024'],
#   ['Disability', 'DBL669171', 'Yes', 'SHELTERPOINT LIFE INS CO', '06/09/2024'],
#   'None'],
#  ['Date Issued:07/23/2010',
#   'Contractor ID:605253',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:595 EAST 4TH STREET 2ND FLOOR   BROOKLYN, NY 11218',
#   'Business 1:MD. JOYNAL ABEDIN',
#   'Business 1:MD. JOYNAL ABEDIN',
#   [],
#   ['General Liability', 'ART8143721', 'Yes', 'UTICA FIRST', '02/27/2017'],
#   ["Workers' Compensation", 'K 2013 751-9', 'Yes', 'NYSIF', '02/05/2017'],
#   'None'],
#  ['Date Issued:07/23/2020',
#   'Contractor ID:622000',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:284 EAST 3RD STREET   BROOKLYN, NY 11218',
#   'Business 1:WARDA CONTRACTING INC',
#   'Business 1:WARDA CONTRACTING INC',
#   ['General Liability',
#    'ART3000624320',
#    'Yes',
#    'UTICA FIRST INS CO',
#    '10/20/2023'],
#   ["Workers' Compensation", 'K2414 777-9', 'Yes', 'NYSIF', '04/24/2023'],
#   ['Disability', 'DBL 6931 80 - 3', 'Yes', 'NYSIF', '09/17/2023'],
#   'None'],
#  ['Date Issued:03/09/2011',
#   'Contractor ID:606523',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:372 E 32ND STREET   BKLYN, NY 11226',
#   'Business 1:ZANIAL ABEDIN',
#   'Business 1:ZANIAL ABEDIN',
#   [],
#   ['General Liability', '', 'Yes', 'UTICA FIRST INS CO', '07/17/2011'],
#   ["Workers' Compensation", '', 'Yes', 'NYSIF', '04/11/2012'],
#   'None'],
#  ['Date Issued:05/11/2020',
#   'Contractor ID:612485',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:180 BEACH 101ST UNIT 3B   ROCKAWAY PARK, NY 11694',
#   'Business 1:DANCOBY INC',
#   'Business 1:DANCOBY INC',
#   ['General Liability',
#    'WS554694',
#    'Yes',
#    'NORTHFIELD INSURANCE CO',
#    '04/12/2024'],
#   ["Workers' Compensation",
#    'Q2332 164-9',
#    'Yes',
#    'NEW YORK STATE INS FUND',
#    '04/19/2024'],
#   ['Disability',
#    'R12757-000',
#    'Yes',
#    'STD SEC LIFE INS CO OF NY',
#    '05/03/2024'],
#   'None'],
#  ['Date Issued:06/25/2008',
#   'Contractor ID:600610',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:142 MINEOLA AVE   ROSLYN HEIGHTS, NY 11577',
#   'Business 1:DANCOBY FINE RENOVATIONS',
#   'Business 1:DANCOBY FINE RENOVATIONS',
#   ['General Liability',
#    'ART126027705',
#    'Yes',
#    'UTICA 1ST INS CO',
#    '09/13/2010'],
#   ["Workers' Compensation", 'H 2083 904-9', 'Yes', 'NYSIF', '09/11/2010'],
#   ['Disability', '5367704-001', 'Yes', 'ZURICH AME INS CO', '06/06/2010'],
#   'None'],
#  ['Date Issued:07/19/2016',
#   'Contractor ID:616120',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:31-14 8TH STREET   EAST ELMHURST, NY 11370',
#   'Business 1:1 BEST CONSTRUCTION CORP',
#   'Business 1:1 BEST CONSTRUCTION CORP',
#   ['General Liability',
#    'SII3303A20839',
#    'Yes',
#    'UNITED SPECIALTY INS',
#    '12/01/2016'],
#   ["Workers' Compensation", 'Q2377 516-6', 'Yes', 'NYSIF', '11/14/2016'],
#   ['Disability', 'DBL478353', 'Yes', 'SHELTERPOINT LIFE INS CO', '12/07/2017'],
#   'None'],
#  ['Date Issued:07/23/2015',
#   'Contractor ID:614462',
#   'Status:A - ACTIVE',
#   'City Employee: No',
#   'Office Address:99 MADISON AVE FL 620   NEW YORK, NY 10016',
#   'Business 1:LIU ELECTRIC LLC',
#   'Business 1:LIU ELECTRIC LLC',
#   ['General Liability',
#    'L3570006272',
#    'Yes',
#    'ATLANTIC CASUALTY INS CO',
#    '08/28/2023'],
#   ["Workers' Compensation",
#    '92C4Z0048',
#    'Yes',
#    'STATE FARM FIRE & CAS',
#    '03/24/2024'],
#   ['Disability', 'DBL459658', 'Yes', 'SHELTERPOINT LIFE INS CO', '02/08/2024'],
#   'None'],
#  ['Date Issued:10/13/2009',
#   'Contractor ID:016186',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:52 SOUTH TYON AVE   FLORAL  PARK, NY 11001',
#   'Business 1:ABSOLUTE COMFORT, INC',
#   'Business 1:ABSOLUTE COMFORT, INC',
#   ['General Liability',
#    'BOPI057814',
#    'Yes',
#    'MERCHANTS INSURANCE GROUP',
#    '05/11/2018'],
#   ["Workers' Compensation",
#    'WEC BQ3442',
#    'Yes',
#    'PROPERTY & CASUALTY INS C',
#    '05/11/2018'],
#   ['Disability', '0179670', 'Yes', 'WESCO', '12/31/2019'],
#   'None'],
#  ['RUSTAM                      ABILOV',
#   'Date Registered:02/08/2018',
#   'Contractor ID:618578',
#   'Status:A - ACTIVE',
#   'Expiration:06/21/2025',
#   'City Employee: No',
#   'Office Address:11-03 36TH AVENUE   LONG ISLAND CITY, NY 11106',
#   'Business Phone:347-886-4429',
#   'Business 1:HELMSLEY GROUP INC',
#   ["Workers' Compensation",
#    'HEWC345018',
#    'Yes',
#    'NORGUARD INS COMPANY',
#    '03/31/2024'],
#   ['Disability',
#    'Z04318-000',
#    'Yes',
#    "STAN'D SEC LIFE INS CO NY",
#    '02/12/2024'],
#   ['\xa0'],
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['BISHAL                      ABIR',
#   'Date Registered:10/22/2009',
#   'Contractor ID:603122',
#   'Status:E - EXPIRED',
#   'Expiration:10/22/2012',
#   'City Employee: No',
#   'Office Address:478 MCDONALD AVENUE   BROOKLYN, NY 11218',
#   'Business Phone:718-871-5355',
#   'Business 1:TUDIPA CONSTRUCTION CORP',
#   ["Workers' Compensation",
#    'K20781522',
#    'Yes',
#    'NYS INSURANCE FUND',
#    '06/23/2010'],
#   ['Disability', 'DBL5861450', 'Yes', 'NYS INSRUANCE FUND', '06/21/2010'],
#   ['\xa0'],
#   'Status:ACTIVEType:DM - DEMOLITION',
#   'Status:ACTIVEType:CC - CONCRETE'],
#  ['RICHARD                     ABIRIZK',
#   'Date Registered:03/22/2010',
#   'Contractor ID:021548',
#   'Status:H - ON HOLD',
#   'Expiration:02/07/2026',
#   'City Employee: No',
#   'Office Address:29 WARREN STREET   HASTINGS-ON-HUDSON, NY 10706',
#   'Business Phone:914-613-9523',
#   'Business 1:A.R. BROTHERS CONSTRUCTIO',
#   ["Workers' Compensation",
#    '3103W7352',
#    'Yes',
#    'UNITED FARM FAMILY INS CO',
#    '12/11/2023'],
#   ['Disability',
#    'LNY-337233',
#    'Yes',
#    'HARTFORD LIFE ACCNDT INS',
#    '12/31/2023'],
#   ['\xa0']],
#  ['TJO                       N ABIRIZK',
#   'Date Registered:03/22/2010',
#   'Contractor ID:601937',
#   'Status:A - ACTIVE',
#   'Expiration:01/31/2026',
#   'City Employee: No',
#   'Office Address:29 WARREN STREET   HASTINGS-ON-HUDSON, NY 10706',
#   'Business Phone:914-613-9523',
#   'Business 1:J.R. GROUP OF NEW YORK IN',
#   ["Workers' Compensation",
#    '3103W7352',
#    'Yes',
#    'UNITED FARM FAMILY INS CO',
#    '12/11/2023'],
#   ['Disability',
#    'LNY-337233',
#    'Yes',
#    'HARTFORD LIFE & ACCNDT IN',
#    '12/31/2023'],
#   ['\xa0']],
#  ['Date Issued:08/18/2008',
#   'Contractor ID:600969',
#   'Status:E - EXPIRED',
#   'City Employee: No',
#   'Office Address:21 PARK PLAC E   NYC, NY 10007',
#   'Business 1:UNITED CHAMBERS TRADING',
#   'Business 1:UNITED CHAMBERS TRADING',
#   ['General Liability', '', 'No', '', ''],
#   ["Workers' Compensation", 'G 1116 656-8', 'Yes', 'NYSIF', '03/01/2016'],
#   ['Disability', '00000', 'Yes', 'GUARDIAN LIFE INS CO', '10/12/2008'],
#   'None']]

# %%
firstPage = pd.DataFrame(allFinalData)

# %%
firstPage.to_csv("FirstPage.csv", index=False)
